# %%
import pandas as pd

# %%
PATH = "./with_closed_ations_as________select_app_2018_X5_STORES.csv"
df = pd.read_csv(PATH)
df
# Out:
# C:\Users\Dmitry\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          id_applicant  id_partner  id_log  department_id  \
# 0             3080432     2883423      -1           9044
# 1             2873477     2761171      -1          32087
# 2             2896621     2776555      -1          32087
# 3             2906437     2782282      -1          32087
# 4             2965200     2816229      -1          32087
# ...               ...         ...     ...            ...
# 7211284       3221933     2968967      -1          25660
# 7211285       3007369     2840731      -1          10687
# 7211286       3230514     2974049      -1          10718
# 7211287       3117018     2905192      -1          10718
# 7211288       2581506     2596820      -1          10718
#
#                            action_date  \
# 0         2018-10-16 18:11:10.00318+00
# 1        2018-08-15 10:36:32.936322+00
# 2        2018-08-22 14:09:27.083354+00
# 3        2018-08-24 15:55:27.912704+00
# 4        2018-09-11 15:00:49.242929+00
# ...                                ...
# 7211284  2020-04-23 15:05:45.859137+00
# 7211285  2020-04-23 15:05:45.859137+00
# 7211286  2020-04-23 15:05:45.859137+00
# 7211287  2020-04-23 15:05:45.859137+00
# 7211288  2020-04-23 15:05:45.859137+00
#
#                                          stage_name  \
# 0                                Создание кандидата
# 1                                Создание кандидата
# 2                                Создание кандидата
# 3                                Создание кандидата
# 4                                Создание кандидата
# ...                                             ...
# 7211284                    Интервью с руководителем
# 7211285                                  Оформление
# 7211286                                  Оформление
# 7211287  Назначение времени на оформление/медосмотр
# 7211288                                    Ожидание
#
#                                              activity_name result_name  \
# 0                                                      NaN         NaN
# 1                                                      NaN         NaN
# 2                                                      NaN         NaN
# 3                                                      NaN         NaN
# 4                                                      NaN         NaN
# ...                                                    ...         ...
# 7211284         Узнать результаты интервью с руководителем         NaN
# 7211285                           Узнать результаты приема         NaN
# 7211286                           Узнать результаты приема         NaN
# 7211287  Назначить время на оформление/медосмотр (недоз...         NaN
# 7211288                                  Вернуть в воронку         NaN
#
#            position_name  is_active_action  is_open_action
# 0        Продавец-кассир              True           False
# 1        Продавец-кассир              True           False
# 2        Продавец-кассир              True           False
# 3        Продавец-кассир              True           False
# 4        Продавец-кассир              True           False
# ...                  ...               ...             ...
# 7211284  Продавец-кассир              True            True
# 7211285  Продавец-кассир              True            True
# 7211286  Продавец-кассир              True            True
# 7211287  Продавец-кассир              True            True
# 7211288  Продавец-кассир              True            True
#
# [7211289 rows x 11 columns]

# %%
df['position_name'].unique()
# Out:
# array(['Продавец-кассир', 'Заместитель Директора магазина',
#        'Кладовщик-комплектовщик', 'Товаровед-приемщик', 'Оператор склада',
#        'Директор магазина', 'Специалист по документообороту',
#        'Администратор', 'Водитель электроштабелера',
#        'Оператор склада (Вахта)', 'Супервайзер',
#        'Водитель электроштабелера (Вахта)', 'Старший Продавец-кассир',
#        'Супервайзер_NEW_ВК', 'Заместитель Директора магазина_Резерв',
#        'Продавец-кассир (Вахта СПБ)', 'Супервайзер_OLD', 'ТЕСТ',
#        'Продавец-кассир_Подработка', 'Кладовщик-комплектовщик (Вахта)',
#        'Администратор_Резерв', 'Приемщик товара',
#        'Директор магазина_Резерв', 'Старший Продавец-кассир стажер',
#        'Супервайзер_Резерв', 'Оператор технологической линии',
#        'Кладовщик по отгрузке', 'Специалист по документообороту (Вахта)'],
#       dtype=object)

# %%
df.isna().sum()
# Out:
# id_applicant              0
# id_partner                0
# id_log                    0
# department_id             0
# action_date               0
# stage_name                0
# activity_name       1539630
# result_name         1510719
# position_name             0
# is_active_action          0
# is_open_action            0
# dtype: int64

# %%
from collections import Counter
from matplotlib.pyplot import figure

import matplotlib.pyplot as plt
# positions = df['position_name'].unique()
column_name = 'result_name'
df_temp = df[df[column_name].notna()]
position_counts = Counter(df_temp[column_name])
df_pos =  df_temp.from_dict(position_counts, orient='index')
df_pos = df_pos.sort_values(by=[0], ascending = False)

plt.figure(figsize=(20, 20))
df_pos[df_pos[0]>5000].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_pos[df_pos[0]>5000]
# Out:
#                                                      0
# Подходит                                       1576735
# Встреча назначена                               797349
# Недозвон                                        590486
# Отказ кандидата                                 500688
# Нет обратной связи                              399692
# Подготовлена                                    383658
# Источник не Яндекс Цифра                        241036
# Время назначено                                 226840
# В ожидании                                      204256
# Не подходит                                     157819
# Резерв                                          145594
# Принят                                          138830
# Перенос кандидата                                89799
# Не резерв                                        80862
# Ожидание                                         43835
# Не подготовлена                                  20999
# Направлен на медосмотр                           13143
# Внешний кандидат                                 10382
# Перенос звонка                                    9586
# Уточнение данных                                  7119
# Заполнено                                         5292
# Вложено                                           4806
# Назначить время на оформление/медосмотр           4606
# Интервью с руководителем                          4182
# Согласование повторного приема                    4127
# Получено                                          3886
# Прошел, запросить результаты ГС                   3541
# Не принят                                         3109
# Обработка                                         2972
# Оформление                                        2954
# Нет резюме                                        2862
# Групповое собеседование и тестирование            2639
# Результаты запрошены                              2403
# Отказ руководителя                                2075
# Подходит на СПВ                                   1985
# Не  подходит                                      1371
# Подходит на ДМ/ЗДМ                                1288
# Не получено                                       1045
# Внешний кандидат (Тест)                            971
# Перенос руководителя                               757
# Назначено                                          737
# Гайд-интервью                                      668
# Назначение времени на оформление/медосмотр         660
# Кадровый резерв                                    616
# Назначение времени на собеседование/медосмотр      463
# Не прошел                                          445
# СБ                                                 393
# Источник Яндекс Цифра                              287
# Внутренний кандидат (Оценка)                       130
# Внутренний кандидат (Тест)                         127
# Внутренний кандидат                                120
