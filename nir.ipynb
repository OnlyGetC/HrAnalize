# %% [markdown]
# # По позициям,,,,
# тест удалить,
# резерв, Вахта, вк добавить столбец
#
# # Стадия
# Ожидание9
# Резерв/не резерв - кодирование 1/0 соответственно
# # Bool
# закодировать
# # Questions
# result_name оставить нул?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
PATHES = ["./with_closed_ations_as________select_app_2018_X5_STORES.csv"]
# df = pd.read_csv(PATH)
df = pd.DataFrame()
for path in PATHES:
    df1 = pd.read_csv(path)
    df = pd.concat([df, df1])
# Out:
# C:\Users\Dmitry\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df['stage_name'][df['stage_name'] == 'Отказался new'] = 'Отказался'
# Out:
# C:\Users\Dmitry\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['activity_name'].unique()
# Out:
# array([nan, 'Узнать результаты СБ', 'Провести первичную обработку',
#        'Назначить время на оформление/медосмотр',
#        'Подготовить анкету кандидата',
#        'Узнать результаты интервью с руководителем',
#        'Назначить интервью с руководителем', 'Проверка источника',
#        'Узнать результаты приема', 'Узнать результаты гайд-интервью',
#        'Назначить время для гайд-интервью',
#        'Назначить групповое собеседование и тестирование',
#        'Узнать результаты группового собеседования и тестирования',
#        'Назначить время на оформление/медосмотр (недозвон)',
#        'Вернуть в воронку', 'Проверка формы обращения',
#        'Узнать результаты медосмотра',
#        'Прикрепить резюме/Профиль сотрудника', 'Назначить гайд-интервью',
#        'Проверка кандидата (Тест)',
#        'Получить результаты online тестирования', 'Оценить резюме',
#        'Проверка кандидата (Оценка)', 'Заполнить данные скоринга',
#        'Проверка результатов скоринга', 'Проверка кандидата (Обработка)',
#        'Запросить результаты ГС и тестирования',
#        'Получить согласование повторного приема и отправить в СБ',
#        'Провести гайд-интервью РМП', 'Назначение на оформление',
#        'Провести гайд-интервью НОО', 'Уточнить недостающие данные',
#        'Назначить время на оформление/медосмотр (не доступен)',
#        'Назначить время на оформление', 'Вывести из черного списка',
#        'Узнать результаты стажировки', 'Проверить выход на работу',
#        'Узнать результаты стажировки СПВ', 'Узнать результаты практики'],
#       dtype=object)

# %%
df.isna().sum()
# Out:
# id_applicant              0
# id_partner                0
# id_log                    0
# department_id             0
# action_date               0
# stage_name                0
# activity_name       1539630
# result_name         1510719
# position_name             0
# is_active_action          0
# is_open_action            0
# dtype: int64

# %%
df[df['activity_name'] == 'Провести гайд-интервью НОО']
# Out:
#          id_applicant  id_partner    id_log  department_id  \
# 1136909       2723324     2671744  14067558          16863
# 1147087       2566405     2588847  14763241          16798
# 1150762       3067941     2875835  16174092          33717
# 1151123       3126830     2911253  16382215          16889
# 1157290       3089747     2888987  16035381          16933
# ...               ...         ...       ...            ...
# 7150300       3092644     1273038  17425434          16798
# 7174844       3273223     2999688  17212740          19241
# 7186641       2673556     2646490  20031214          34349
# 7186700       3054605     2867872  15828213          16860
# 7207972       2865777     2756043        -1          16951
#
#                            action_date     stage_name  \
# 1136909  2018-07-12 16:38:04.460192+00  Гайд-интервью
# 1147087  2018-08-17 09:28:48.651373+00  Гайд-интервью
# 1150762  2018-11-02 17:09:05.050066+00  Гайд-интервью
# 1151123   2018-11-16 13:17:12.40041+00  Гайд-интервью
# 1157290  2018-10-25 17:33:30.306275+00  Гайд-интервью
# ...                                ...            ...
# 7150300   2019-01-22 10:42:15.95023+00  Гайд-интервью
# 7174844  2019-01-10 16:29:18.878767+00  Гайд-интервью
# 7186641  2019-06-11 10:53:51.718132+00  Гайд-интервью
# 7186700  2018-10-12 15:03:00.812458+00  Гайд-интервью
# 7207972  2020-04-23 15:05:45.859137+00  Гайд-интервью
#
#                       activity_name             result_name  \
# 1136909  Провести гайд-интервью НОО                Подходит
# 1147087  Провести гайд-интервью НОО  Рекомендован на ДМ/ЗДМ
# 1150762  Провести гайд-интервью НОО                Подходит
# 1151123  Провести гайд-интервью НОО                Подходит
# 1157290  Провести гайд-интервью НОО                Подходит
# ...                             ...                     ...
# 7150300  Провести гайд-интервью НОО                Подходит
# 7174844  Провести гайд-интервью НОО                Подходит
# 7186641  Провести гайд-интервью НОО         Отказ кандидата
# 7186700  Провести гайд-интервью НОО                Подходит
# 7207972  Провести гайд-интервью НОО                     NaN
#
#               position_name  is_active_action  is_open_action
# 1136909         Супервайзер              True           False
# 1147087         Супервайзер              True           False
# 1150762         Супервайзер              True           False
# 1151123         Супервайзер              True           False
# 1157290  Супервайзер_NEW_ВК              True           False
# ...                     ...               ...             ...
# 7150300         Супервайзер              True           False
# 7174844         Супервайзер              True           False
# 7186641         Супервайзер              True           False
# 7186700  Супервайзер_NEW_ВК              True           False
# 7207972         Супервайзер              True            True
#
# [286 rows x 11 columns]

# %%
plt.subplots(figsize=(13,13))
sns.heatmap(df.corr(),annot=True,linewidths = 1)
plt.show()

# %%
from collections import Counter
from matplotlib.pyplot import figure

import matplotlib.pyplot as plt
# positions = df['position_name'].unique()
column_name = 'result_name'
df_temp = df[df[column_name].notna()]
position_counts = Counter(df_temp[column_name])
df_pos =  df_temp.from_dict(position_counts, orient='index')
df_pos = df_pos.sort_values(by=[0], ascending = False)

plt.figure(figsize=(20, 20))
df_pos[df_pos[0]<5000].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_pos[df_pos[0]>5000]
# Out:
#                                 0
# Подходит                  1576735
# Встреча назначена          797349
# Недозвон                   590486
# Отказ кандидата            500688
# Нет обратной связи         399692
# Подготовлена               383658
# Источник не Яндекс Цифра   241036
# Время назначено            226840
# В ожидании                 204256
# Не подходит                157819
# Резерв                     145594
# Принят                     138830
# Перенос кандидата           89799
# Не резерв                   80862
# Ожидание                    43835
# Не подготовлена             20999
# Направлен на медосмотр      13143
# Внешний кандидат            10382
# Перенос звонка               9586
# Уточнение данных             7119
# Заполнено                    5292

# %%
df_pos
# Out:
#                                                   0
# Интервью с руководителем                    1755047
# Обработка                                   1682797
# Создание кандидата                          1131313
# СБ                                           861845
# Оформление                                   487205
# Назначение времени на оформление/медосмотр   458230
# Групповое собеседование и тестирование       368093
# Смена вакансии                               209927
# Гайд-интервью                                 90473
# Резерв                                        52593
# Отказался                                     31346
# Ожидание                                      26054
# Предварительная оценка                        23994
# Ожидание9                                      9970
# Мы отказали                                    6398
# Оценка резюме                                  5240
# Не прошел СБ                                   4153
# Online тестирование                            2965
# Назначение гайд-интервью                       1909
# Подходит на ДМ/ЗДМ                              668
# Выход на работу                                 623
# Выход состоялся                                 231
# Назначение времени на оформление                153
# Кадровый резерв                                  40
# Черный список                                    14
# Стажировка в магазине                             5
# Стажировка СПВ                                    2
# Практика на сложном объекте                       1
